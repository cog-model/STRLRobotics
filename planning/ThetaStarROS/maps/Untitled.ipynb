# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread

# %%
image = imread('second.png')
# image[(image.shape[0] - 1 - 5):(image.shape[0] - 1 - 0), 10:15] = 0
image[0:(image.shape[0] - 1), 10:15] = 100

# %%
plt.figure(figsize=(30, 30))
plt.imshow(image, cmap='gray')
plt.show()

# %%
round(3.5)
# Out:
# 4
